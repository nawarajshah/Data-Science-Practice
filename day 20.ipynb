# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.datasets import make_circles, make_blobs, make_moons
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN, KMeans

# %%
x, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
plt.scatter(x[:,0], x[:,1])

# %%
kmeans = KMeans(n_clusters=4, max_iter=300)
pred_y = kmeans.fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=pred_y)
plt.show()

# %%
x, y = make_circles(n_samples=750, factor=0.3, noise=0.1)
x = StandardScaler().fit_transform(x)
plt.scatter(x[:,0], x[:,1])

# %%
x
# Out:
# array([[-1.9277308 , -0.7967887 ],
#        [ 0.08575651, -0.46941371],
#        [ 0.22241124, -0.39699729],
#        ...,
#        [ 0.10960079, -1.96435336],
#        [-0.5626802 ,  1.68922394],
#        [-0.25747118, -0.26932429]])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
kmeans = KMeans(n_clusters=2, max_iter=300)
pred_y = kmeans.fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=pred_y)
plt.show()

# %%
x, y = make_circles(n_samples=750, factor=0.3, noise=0.1)
x = StandardScaler().fit_transform(x)
y_pred = DBSCAN(eps=0.3).fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=y_pred)

# %%
x, y = make_moons(n_samples=750, shuffle=True, noise=0.1)
x = StandardScaler().fit_transform(x)
plt.scatter(x[:,0], x[:,1])

# %%
kmeans = KMeans(n_clusters=2, max_iter=300)
pred_y = kmeans.fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=pred_y)
plt.show()

# %%
x, y = make_moons(n_samples=750, shuffle=True, noise=0.1)
x = StandardScaler().fit_transform(x)
y_pred = DBSCAN(eps=0.2).fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=y_pred)
